# %% [markdown]
# Estructuras de Datos

# %%
contactos = [
    {"id": 1, "nombre": "Marco", "telefono": "2871104293"},
    {"id": 2, "nombre": "Ana", "telefono": "2871122343"}
]

for contacto in contactos:
    print(contacto["nombre"])
